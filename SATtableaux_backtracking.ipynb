# %% [markdown]
# ## SATtableaux por backtracking
# A continuación correremos cada una de las reglas con SATtableaux profundidad

# %%
from logica import*   
from grafos import*

# %%
g = Grafos()

# %% [markdown]
# ## Regla 1

# %% [markdown]
# Tiempo de ejecución: 46.9ms

# %%
g.visualizar_grafo(r2p)

# %% [markdown]
# ## Regla 3

# %%
# %%time 
A3 = inorder_to_tree(g.reglas[2])
r3p = A3.SATtableaux_anchura()
# Out:
# CPU times: total: 3min 17s
# Wall time: 3min 59s

# %% [markdown]
# Tiempo de ejecución: 3 minutos y 59 segundos

# %%
g.visualizar_grafo(r3p)

# %%
# %%time 
A4 = inorder_to_tree(g.reglas[3])
r4p = A4.SATtableaux_anchura()
# Out:
# CPU times: total: 703 ms
# Wall time: 754 ms
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'A4 = inorder_to_tree(g.reglas[3])\nr4p = A4.SATtableaux_anchura()\n')
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:2
#
# File c:\Users\Arturo\Documents\Proyecto LCC\proyecto-logica-G5\logica.py:115, in Formula.SATtableaux_anchura(self)
#     113 while len(frontera) > 0:
#     114     estado = frontera.pop(0)
# --> 115     hijos = estado.expandir()
#     116     for a in hijos:
#     117         if a != None:
#
# File c:\Users\Arturo\Documents\Proyecto LCC\proyecto-logica-G5\logica.py:533, in nodos_tableaux.expandir(self)
#     531 def expandir(self):
#     532     '''Escoge última alfa, si no última beta, si no None'''
# --> 533     f_alfas = deepcopy(self.alfas)
#     534     f_betas = deepcopy(self.betas)
#     535     f_literales = deepcopy(self.literales)
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:197, in _deepcopy_list(x, memo, deepcopy)
#     195 append = y.append
#     196 for a in x:
# --> 197     append(deepcopy(a, memo))
#     198 return y
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:202, in _deepcopy_tuple(x, memo, deepcopy)
#     201 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 202     y = [deepcopy(a, memo) for a in x]
#     203     # We're not going to put the tuple in the memo, but it's still important we
#     204     # check for it, in case the tuple contains recursive mutable structures.
#     205     try:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
#     [... skipping similar frames: deepcopy at line 163 (739 times), _deepcopy_dict at line 222 (738 times), _reconstruct at line 260 (738 times), deepcopy at line 137 (738 times)]
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:254, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     252 if deep and args:
#     253     args = (deepcopy(arg, memo) for arg in args)
# --> 254 y = func(*args)
#     255 if deep:
#     256     memo[id(x)] = y
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:253, in <genexpr>(.0)
#     251 deep = memo is not None
#     252 if deep and args:
# --> 253     args = (deepcopy(arg, memo) for arg in args)
#     254 y = func(*args)
#     255 if deep:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# Tiempo de ejecución: No ejecuto pues alcanzó stack overflow en 1.4 segundos

# %%
g.visualizar_grafo(r4p)

# %%
# %%time 
A5 = inorder_to_tree(g.reglas[4])
r5p = A5.SATtableaux_anchura()
print(r5p)
# Out:
# CPU times: total: 42min 28s
# Wall time: 1h 31min 36s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'A5 = inorder_to_tree(g.reglas[4])\nr5p = A5.SATtableaux_anchura()\nprint(r5p)\n')
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:2
#
# File c:\Users\Arturo\Documents\Proyecto LCC\proyecto-logica-G5\logica.py:115, in Formula.SATtableaux_anchura(self)
#     113 while len(frontera) > 0:
#     114     estado = frontera.pop(0)
# --> 115     hijos = estado.expandir()
#     116     for a in hijos:
#     117         if a != None:
#
# File c:\Users\Arturo\Documents\Proyecto LCC\proyecto-logica-G5\logica.py:534, in nodos_tableaux.expandir(self)
#     532 '''Escoge última alfa, si no última beta, si no None'''
#     533 f_alfas = deepcopy(self.alfas)
# --> 534 f_betas = deepcopy(self.betas)
#     535 f_literales = deepcopy(self.literales)
#     536 if len(self.alfas) > 0:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:197, in _deepcopy_list(x, memo, deepcopy)
#     195 append = y.append
#     196 for a in x:
# --> 197     append(deepcopy(a, memo))
#     198 return y
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:202, in _deepcopy_tuple(x, memo, deepcopy)
#     201 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 202     y = [deepcopy(a, memo) for a in x]
#     203     # We're not going to put the tuple in the memo, but it's still important we
#     204     # check for it, in case the tuple contains recursive mutable structures.
#     205     try:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:254, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     252 if deep and args:
#     253     args = (deepcopy(arg, memo) for arg in args)
# --> 254 y = func(*args)
#     255 if deep:
#     256     memo[id(x)] = y
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:253, in <genexpr>(.0)
#     251 deep = memo is not None
#     252 if deep and args:
# --> 253     args = (deepcopy(arg, memo) for arg in args)
#     254 y = func(*args)
#     255 if deep:
#
# File c:\Users\Arturo\anaconda3\Lib\copy.py:119, in deepcopy(x, memo, _nil)
#     115 d[bytearray] = bytearray.copy
#     117 del d, t
# --> 119 def deepcopy(x, memo=None, _nil=[]):
#     120     """Deep copy operation on arbitrary Python objects.
#     121
#     122     See the module's __doc__ string for more info.
#     123     """
#     125     d = id(x)
#
# KeyboardInterrupt:

# %% [markdown]
# Tiempo de ejecución: No se ejecutó después de 91 minutos y 46 segundos

# %%
g.visualizar_grafo(r5p)

# %% [markdown]
# ## SATtableaux por backtracking

# %%
A1 = inorder_to_tree(g.reglas[0])
# %time 
r1b = A1.SATtableaux_backtracking()
print(r1b)
# Out:
# CPU times: total: 0 ns
# Wall time: 8.34 μs
# {'ğ': False, 'Ğ': False, 'ĝ': False, 'Ĝ': False, 'ě': False, 'Ě': False, 'ę': False, 'Ę': False, 'ė': False, 'Ė': False, 'ĕ': False, 'Ĕ': False, 'ē': False, 'Ē': False, 'Đ': True, 'đ': False}

# %%
g.visualizar_grafo(r1b)

# %%
A2 = inorder_to_tree(g.reglas[1])
# %time 
r2b = A2.SATtableaux_anchura()
print(r2b)
# Out:
# CPU times: total: 0 ns
# Wall time: 11.7 μs
# {'Ƌ': True, 'Ə': False, 'Ǝ': False, 'ƍ': False, 'ƌ': False, 'Ɗ': False, 'Ɖ': False, 'ƈ': False, 'Ƈ': False, 'Ɔ': False, 'ƅ': False, 'Ƅ': False, 'ƃ': False, 'Ƃ': False, 'ƀ': False, 'Ɓ': False}

# %%
g.visualizar_grafo(r2b)

# %%
A3 = inorder_to_tree(g.reglas[2])
# %time 
r3b = A3.SATtableaux_anchura()
print(r3b)

# %%
g.visualizar_grafo(r3b)

# %%
A4 = inorder_to_tree(g.reglas[3])
# %time 
r4b = A4.SATtableaux_anchura()
print(r4b)

# %%
g.visualizar_grafo(r4b)

# %%
A5 = inorder_to_tree(g.reglas[4])
# %time 
r5b = A5.SATtableaux_anchura()
print(r5b)

# %%
g.visualizar_grafo(r5b)
