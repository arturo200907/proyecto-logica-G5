# %% [markdown]
# ## SATtableaux por backtracking
# A continuación correremos cada una de las reglas con SATtableaux backtracking

# %%
from logica import*   
from grafos import*

# %%
g = Grafos()

# %% [markdown]
# ## Regla 1

# %%
# %%time 
A1 = inorder_to_tree(g.reglas[0])

r1b = A1.SATtableaux_backtracking()
# Out:
# CPU times: total: 15.6 ms
# Wall time: 11.4 ms

# %% [markdown]
# Tiempo de ejecución: 15.6ms

# %%
g.visualizar_grafo(r1b)

# %% [markdown]
# ## Regla 2

# %%
# %%time 
A2 = inorder_to_tree(g.reglas[1])
r2b = A2.SATtableaux_backtracking()
# Out:
# CPU times: total: 15.6 ms
# Wall time: 18.7 ms

# %% [markdown]
# Tiempo de ejecución: 15.6 ms

# %%
g.visualizar_grafo(r2b)

# %% [markdown]
# ## Regla 3

# %%
# %%time 
A3 = inorder_to_tree(g.reglas[2])

r3b = A3.SATtableaux_backtracking()
print(r3b)
# Out:
# {'Ď': True, 'Č': True, 'Ċ': True, 'Ĉ': True, 'Ć': True, 'Ą': True, 'Ā': True, 'Ă': True}
# CPU times: total: 141 ms
# Wall time: 157 ms

# %% [markdown]
# Tiempo de ejecución: 141ms

# %%
g.visualizar_grafo(r3b)

# %%
import sys 
sys.setrecursionlimit(10000)

# %% [markdown]
# ## Regla 4

# %%
# %%time 
A4 = inorder_to_tree(g.reglas[3])
r4b = A4.SATtableaux_anchura()

# %% [markdown]
# Tiempo de ejecución: No corrió después de 903 minutos y 54 segundos

# %%
g.visualizar_grafo(r4b)

# %% [markdown]
# ## Regla 5

# %%
# %%time 
A5 = inorder_to_tree(g.reglas[4])
r5b = A5.SATtableaux_backtracking()
print(r5b)
# Out:
# {'ů': False, 'Ů': False, 'ŭ': False, 'Ŭ': False, 'ū': False, 'Ū': False, 'ũ': False, 'Ũ': False, 'ŧ': False, 'Ŧ': False, 'ť': False, 'Ť': False, 'ţ': False, 'Ţ': False, 'š': False, 'Š': False, 'ş': False, 'Ş': False, 'ŝ': False, 'Ŝ': False, 'ś': False, 'Ś': False, 'ř': False, 'Ř': False, 'ŗ': False, 'Ŗ': False, 'ŕ': False, 'Ŕ': False, 'œ': False, 'Œ': False, 'ő': False, 'Ő': False, 'ŏ': False, 'Ŏ': False, 'ō': False, 'Ō': False, 'ŋ': False, 'Ŋ': False, 'ŉ': False, 'ň': False, 'Ň': False, 'ņ': False, 'Ņ': False, 'ń': False, 'Ń': False, 'ł': False, 'Ł': False, 'ŀ': False, 'Ŀ': False, 'ľ': False, 'Ľ': False, 'ļ': False, 'Ļ': False, 'ĺ': False, 'Ĺ': False, 'ĸ': False, 'ķ': False, 'Ķ': False, 'ĵ': False, 'Ĵ': False, 'ĳ': False, 'Ĳ': False, 'ı': False, 'İ': False, 'į': False, 'Į': False, 'ĭ': False, 'Ĭ': False, 'ī': False, 'Ī': False, 'ĩ': False, 'Ĩ': False, 'ħ': False, 'Ħ': False, 'ĥ': False, 'Ĥ': False, 'ģ': False, 'Ģ': False, 'ġ': False, 'Ġ': False, 'ğ': False, 'Ğ': False, 'ĝ': False, '
# ...

# %% [markdown]
# Tiempo de ejecución: 1.87 segundos

# %%
g.visualizar_grafo(r5b)

# %% [markdown]
# Observe que está solución es correcta para la regla 5 pues como no existe una restricción que obligue a que exista alguna arista recorrida, la regla se vuelve verdadera por vacuidad.
