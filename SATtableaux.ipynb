# %% [markdown]
# ## SATtableaux
# A continuación correremos cada una de las reglas con SATtableaux anchura, profundidad y backtracking y mostraremos su tiempo de ejecución.

# %%
from logica import*   
from grafos import*

# %%
g = Grafos()

# %% [markdown]
# ## SATtableaux por anchura

# %%
A1 = inorder_to_tree(g.reglas[0])
# %time 
r1a = A1.SATtableaux_anchura()
print(r1a)
# Out:
# CPU times: total: 0 ns
# Wall time: 8.58 μs
# {'ğ': False, 'Ğ': False, 'ĝ': False, 'Ĝ': False, 'ě': False, 'Ě': False, 'ę': False, 'Ę': False, 'ė': False, 'Ė': False, 'ĕ': False, 'ē': False, 'Ē': False, 'đ': False, 'Ĕ': True, 'Đ': False}

# %%
g.visualizar_grafo(r1a)

# %%
A2 = inorder_to_tree(g.reglas[1])
# %time 
r2a = A2.SATtableaux_anchura()
print(r2a)
# Out:
# CPU times: total: 0 ns
# Wall time: 7.39 μs
# {'Ƌ': True, 'Ə': False, 'Ǝ': False, 'ƍ': False, 'ƌ': False, 'Ɗ': False, 'Ɖ': False, 'ƈ': False, 'Ƈ': False, 'Ɔ': False, 'ƅ': False, 'Ƅ': False, 'ƃ': False, 'Ƃ': False, 'ƀ': False, 'Ɓ': False}

# %%
g.visualizar_grafo(r2a)

# %%
A3 = inorder_to_tree(g.reglas[2])
# %time 
r3a = A3.SATtableaux_anchura()
print(r3a)
# Out:
# CPU times: total: 0 ns
# Wall time: 6.91 μs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 A3 = inorder_to_tree(g.reglas[2])
#       2 get_ipython().run_line_magic('time', '')
# ----> 3 r3 = A3.SATtableaux_anchura()
#       4 print(r3)
#
# File ~\Downloads\proyecto-logica-G5-main\proyecto-logica-G5-main\logica.py:114, in Formula.SATtableaux_anchura(self)
#     112 while len(frontera) > 0:
#     113     estado = frontera.pop(0)
# --> 114     hijos = estado.expandir()
#     115     for a in hijos:
#     116         if a != None:
#
# File ~\Downloads\proyecto-logica-G5-main\proyecto-logica-G5-main\logica.py:573, in nodos_tableaux.expandir(self)
#     571     B2 = f.right
#     572 f_alfas2 = deepcopy(f_alfas)
# --> 573 f_betas2 = deepcopy(f_betas)
#     574 f_literales2 = deepcopy(f_literales)
#     575 clasf = B1.clasifica_para_tableaux()
#
# ...

# %%
g.visualizar_grafo(r3a)

# %%
A4 = inorder_to_tree(g.reglas[3])
# %time 
r4a = A4.SATtableaux_anchura()
print(r4a)

# %%
g.visualizar_grafo(r4a)

# %%
A5 = inorder_to_tree(g.reglas[4])
# %time 
r5a = A5.SATtableaux_anchura()
print(r5a)

# %%
g.visualizar_grafo(r5a)

# %% [markdown]
# ## SATtableaux por profundidad

# %%
A1 = inorder_to_tree(g.reglas[0])
# %time 
r1p = A1.SATtableaux_profundidad()
print(r1p)
# Out:
# CPU times: total: 0 ns
# Wall time: 8.11 μs
# {'ğ': False, 'Ğ': False, 'ĝ': False, 'Ĝ': False, 'ě': False, 'Ě': False, 'ę': False, 'Ę': False, 'ė': False, 'Ė': False, 'ĕ': False, 'ē': False, 'Ē': False, 'đ': False, 'Ĕ': True, 'Đ': False}

# %%
g.visualizar_grafo(r1p)

# %%
A2 = inorder_to_tree(g.reglas[1])
# %time 
r2p = A2.SATtableaux_anchura()
print(r2p)
# Out:
# CPU times: total: 0 ns
# Wall time: 9.06 μs
# {'Ƌ': True, 'Ə': False, 'Ǝ': False, 'ƍ': False, 'ƌ': False, 'Ɗ': False, 'Ɖ': False, 'ƈ': False, 'Ƈ': False, 'Ɔ': False, 'ƅ': False, 'Ƅ': False, 'ƃ': False, 'Ƃ': False, 'ƀ': False, 'Ɓ': False}

# %%
g.visualizar_grafo(r2p)

# %%
A3 = inorder_to_tree(g.reglas[2])
# %time 
r3p = A3.SATtableaux_anchura()
print(r3p)

# %%
g.visualizar_grafo(r3p)

# %%
A4 = inorder_to_tree(g.reglas[3])
# %time 
r4p = A4.SATtableaux_anchura()
print(r4p)

# %%
g.visualizar_grafo(r4p)

# %%
A5 = inorder_to_tree(g.reglas[34])
# %time 
r5p = A5.SATtableaux_anchura()
print(r5p)

# %%
g.visualizar_grafo(r5p)

# %% [markdown]
# ## SATtableaux por backtracking

# %%
A1 = inorder_to_tree(g.reglas[0])
# %time 
r1b = A1.SATtableaux_backtracking()
print(r1b)
# Out:
# CPU times: total: 0 ns
# Wall time: 8.34 μs
# {'ğ': False, 'Ğ': False, 'ĝ': False, 'Ĝ': False, 'ě': False, 'Ě': False, 'ę': False, 'Ę': False, 'ė': False, 'Ė': False, 'ĕ': False, 'Ĕ': False, 'ē': False, 'Ē': False, 'Đ': True, 'đ': False}

# %%
g.visualizar_grafo(r1b)

# %%
A2 = inorder_to_tree(g.reglas[1])
# %time 
r2b = A2.SATtableaux_anchura()
print(r2b)
# Out:
# CPU times: total: 0 ns
# Wall time: 11.7 μs
# {'Ƌ': True, 'Ə': False, 'Ǝ': False, 'ƍ': False, 'ƌ': False, 'Ɗ': False, 'Ɖ': False, 'ƈ': False, 'Ƈ': False, 'Ɔ': False, 'ƅ': False, 'Ƅ': False, 'ƃ': False, 'Ƃ': False, 'ƀ': False, 'Ɓ': False}

# %%
g.visualizar_grafo(r2b)

# %%
A3 = inorder_to_tree(g.reglas[2])
# %time 
r3b = A3.SATtableaux_anchura()
print(r3b)

# %%
g.visualizar_grafo(r3b)

# %%
A4 = inorder_to_tree(g.reglas[3])
# %time 
r4b = A4.SATtableaux_anchura()
print(r4b)

# %%
g.visualizar_grafo(r4b)

# %%
A5 = inorder_to_tree(g.reglas[4])
# %time 
r5b = A5.SATtableaux_anchura()
print(r5b)

# %%
g.visualizar_grafo(r5b)
