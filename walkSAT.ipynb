# %% [markdown]
# ## WALKSAT

# %%
from logica import*   
from grafos import*

# %%
g=Grafos()

# %%
def filtro(dict_tseitin, regla): 
    h = inorder_to_tree(regla) 
    letras = h.letras()
    for letter in dict_tseitin.copy(): 
        if letter not in letras: 
            del dict_tseitin[letter] 

    return dict_tseitin

# %% [markdown]
# ## Regla 1

# %%
# %%time 
#REGLA 1
A1 = g.reglas[0]
ts1 = tseitin(A1)   
r1 = walkSAT(ts1) 
I1 = filtro(r1[1], A1)
# Out:
# CPU times: total: 0 ns
# Wall time: 23.6 μs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '#REGLA 1\nA1 = g.reglas[0]\nts1 = tseitin(A1)   \nr1 = walkSAT(ts1) \nI1 = filtro(r1[1], A1) \n')
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:2
#
# NameError: name 'g' is not defined

# %%
g.visualizar_grafo(I1)

# %% [markdown]
# ## Regla 2

# %%
# %%time  
#REGLA 2
A2 = g.reglas[1] 
ts2 = tseitin(A2)   
r2 = walkSAT(ts2)
I2 = filtro(r2[1], A2)
# Out:
# CPU times: total: 0 ns
# Wall time: 22.9 μs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '#REGLA 2\nA2 = g.reglas[1] \nts2 = tseitin(A2)   \nr2 = walkSAT(ts2)\nI2 = filtro(r2[1], A2) \n')
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:2
#
# NameError: name 'g' is not defined

# %%
g.visualizar_grafo(I2)

# %% [markdown]
# ## Regla 3

# %%
# %%time  
#Regla 3 
A3 = g.reglas[2] 
ts3 = tseitin(A3)   
r3 = walkSAT(ts3)
I3 = filtro(r3[1], A3)
# Out:
# CPU times: total: 0 ns
# Wall time: 19.3 μs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '#Regla 3 \nA3 = g.reglas[2] \nts3 = tseitin(A3)   \nr3 = walkSAT(ts3)\nI3 = filtro(r3[1], A3) \n')
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:2
#
# NameError: name 'g' is not defined

# %%
g.visualizar_grafo(I3,custom_size=(10,10))

# %% [markdown]
# ## Regla 4

# %%
# %%time  
#Regla 4
A4 = g.reglas[3] 
ts4 = tseitin(A4)   
r4 = walkSAT(ts4, max_flips=10000, max_tries=5000, p=0.2) 
I4 = filtro(r4[1], A4)
# Out:
# CPU times: total: 8h 7min 31s
# Wall time: 8h 25min 27s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '#Regla 4\nA4 = g.reglas[3] \nts4 = tseitin(A4)   \nr4 = walkSAT(ts4, max_flips=10000, max_tries=5000, p=0.2) \nI4 = filtro(r4[1], A4)\n')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:4
#
# File ~\Downloads\proyecto-logica-G5-main (2)\proyecto-logica-G5-main\logica.py:846, in walkSAT(A, max_flips, max_tries, p)
#     844                 v = min_breaks[0]
#     845         I = flip_literal(w.I, v)
# --> 846         w.actualizar(I)
#     847 return None, {}
#
# File ~\Downloads\proyecto-logica-G5-main (2)\proyecto-logica-G5-main\logica.py:812, in WalkSatEstado.actualizar(self, I)
#     810 self.I = I
#     811 self.I_lits = set([p for p in self.letrasp if self.I[p]] + ['-'+p for p in self.letrasp if not self.I[p]])
# --> 812 self.clausulas_sat = [C for C in self.S if any((True for x in self.I_lits if x in C))]
#     813 self.clausulas_unsat = [C for C in self.S if C not in self.clausulas_sat]
#
# File ~\Downloads\proyecto-logica-G5-main (2)\proyecto-logica-G5-main\logica.py:812, in <genexpr>(.0)
#     810 self.I = I
#     811 self.I_lits = set([p for p in self.letrasp if self.I[p]] + ['-'+p for p in self.letrasp if not self.I[p]])
# --> 812 self.clausulas_sat = [C for C in self.S if any((True for x in self.I_lits if x in C))]
#     813 self.clausulas_unsat = [C for C in self.S if C not in self.clausulas_sat]
#
# KeyboardInterrupt:

# %%
g.visualizar_grafo(I4)

# %% [markdown]
# ## Regla 5

# %%
# %%time  
#Regla 5
A5 = g.reglas[4] 
ts5 = tseitin(A5)   
r5 = walkSAT(ts5)
I5 = filtro(r5[1], A5)
# Out:
# CPU times: total: 1min 8s
# Wall time: 1min 15s

# %%
g.visualizar_grafo(I5)

# %% [markdown]
# ## Todas las reglas

# %%
# %%time
reglas = Ytoria([g.reglas[2], g.reglas[3],g.reglas[0],g.reglas[1],g.reglas[4]])
A = reglas  
ts = tseitin(A) 
r = walkSAT(ts)
I = filtro(r[1], A) 
g.visualizar_grafo(I)
# Out:
# CPU times: total: 6h 29min 3s
# Wall time: 6h 43min 50s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'reglas = Ytoria([g.reglas[2], g.reglas[3],g.reglas[0],g.reglas[1],g.reglas[4]])\nA = reglas  \nts = tseitin(A) \nr = walkSAT(ts)\nI = filtro(r[1], A) \ng.visualizar_grafo(I)\n')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:4
#
# File ~\Downloads\proyecto-logica-G5-main (2)\proyecto-logica-G5-main\logica.py:846, in walkSAT(A, max_flips, max_tries, p)
#     844                 v = min_breaks[0]
#     845         I = flip_literal(w.I, v)
# --> 846         w.actualizar(I)
#     847 return None, {}
#
# File ~\Downloads\proyecto-logica-G5-main (2)\proyecto-logica-G5-main\logica.py:813, in WalkSatEstado.actualizar(self, I)
#     811 self.I_lits = set([p for p in self.letrasp if self.I[p]] + ['-'+p for p in self.letrasp if not self.I[p]])
#     812 self.clausulas_sat = [C for C in self.S if any((True for x in self.I_lits if x in C))]
# --> 813 self.clausulas_unsat = [C for C in self.S if C not in self.clausulas_sat]
#
# KeyboardInterrupt:
