# %% [markdown]
# ## WALKSAT

# %%
from logica import*   
from grafos import*

# %%
g=Grafos()

# %%
def filtro(dict_tseitin, regla): 
    h = inorder_to_tree(regla) 
    letras = h.letras()
    for letter in dict_tseitin.copy(): 
        if letter not in letras: 
            del dict_tseitin[letter] 

    return dict_tseitin

# %%
# %%time 
#REGLA 1
A1 = g.reglas[0]
ts1 = tseitin(A1)   
r1 = walkSAT(ts1) 
I1 = filtro(r1[1], A1)
# Out:
# CPU times: total: 0 ns
# Wall time: 7.38 ms

# %%
g.visualizar_grafo(I1)

# %%
# %%time  
#REGLA 2
A2 = g.reglas[1] 
ts2 = tseitin(A2)   
r2 = walkSAT(ts2)
I2 = filtro(r2[1], A2)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 33.3 ms

# %%
g.visualizar_grafo(I2)

# %%
# %%time  
#Regla 3 
A3 = g.reglas[2] 
ts3 = tseitin(A3)   
r3 = walkSAT(ts3)
I3 = filtro(r3[1], A3)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 9.27 ms

# %%
g.visualizar_grafo(I3,custom_size=(10,10))

# %%
# %%time  
#Regla 4
A4 = g.reglas[3] 
ts4 = tseitin(A4)   
r4 = walkSAT(ts4, max_flips=10000, max_tries=5000, p=0.7) 
I4 = filtro(r4[1], A4)
# Out:
# CPU times: total: 42min 55s
# Wall time: 49min 25s

# %%
I4
# Out:
# {}

# %%
g.visualizar_grafo(I4)

# %%
# %%time  
#Regla 5
A5 = g.reglas[4] 
ts5 = tseitin(A5)   
r5 = walkSAT(ts5)
I5 = filtro(r5[1], A5)
# Out:
# CPU times: total: 125 ms
# Wall time: 136 ms

# %%
g.visualizar_grafo(I5)

# %%
# %%time
reglas = Ytoria([g.reglas[2], g.reglas[3],g.reglas[0],g.reglas[1],g.reglas[4]])
A = reglas  
ts = tseitin(A) 
r = walkSAT(ts)
I = filtro(r[1], A) 
g.visualizar_grafo(I)
# Out:
# CPU times: total: 13 s
# Wall time: 15.7 s
