# %% [markdown]
# <h1>Borrador de Nicolas </h1>
# <p>Bienvenido a tu borrador Nicolas, utilizalo para testear código antes de ponerlo en el solucion.ipynb o antes de ponerlo en logica.py o grafos.py. <strong>Es fundamental que primero trabajes en este y si solo si funciona aquí lo pongas en los archivos oficiales para no tener problemas. No olvides guardar con los comandos después de cada sección y sonreir ante cualquier reto </strong> </p>

# %%
import sys
import os
#Codigo para importar grafos y logica pues estan en una carpeta afuera
ruta_proyecto = r"C:\Users\Arturo\Documents\Proyecto LCC\proyecto-logica-G5"
# Si no está en el sistema se agrega.
if ruta_proyecto not in sys.path:
    sys.path.append(ruta_proyecto)

# Como ya está en el sistema ya se podría importar
try:
    import logica   
    print(" Módulo lógica cargado exitosamente")
except ModuleNotFoundError:
    print(" No se encontró el archivo. Revisa que el nombre sea correcto.") 
try:
    import grafos  
    print(" Módulo grafos cargado exitosamente")
except ModuleNotFoundError:
    print(" No se encontró el archivo. Revisa que el nombre sea correcto.")
