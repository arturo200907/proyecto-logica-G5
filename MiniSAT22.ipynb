# %% [markdown]
# ## MINSAT 22
# A continuación se buscará un modelo para las reglas y el problema utilizando el SATsolver `MINSAT 22`

# %%
from logica import*   
from grafos import*

# %%
# !pip install pycosat
# !pip install python-sat
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 16.4 MB/s  0:00:00
# ...

# %%
g=Grafos()

# %% [markdown]
# ## Regla 1

# %%
# %%time
A1 = g.reglas[0]
A = inorder_to_tree(A1)  
I1a = SATsolver(A1)
I1 = filtro(I1a[1], A1)
# Out:
# (((((((((((((((((ĀY-ā)Y-Ă)Y-ă)Y-Ą)Y-ą)Y-Ć)Y-ć)Y-Ĉ)Y-ĉ)Y-Ċ)Y-ċ)Y-Č)Y-č)Y-Ď)Y-ď)O(((((((((((((((ĂY-Ā)Y-ā)Y-ă)Y-Ą)Y-ą)Y-Ć)Y-ć)Y-Ĉ)Y-ĉ)Y-Ċ)Y-ċ)Y-Č)Y-č)Y-Ď)Y-ď))O(((((((((((((((ĄY-Ā)Y-ā)Y-Ă)Y-ă)Y-ą)Y-Ć)Y-ć)Y-Ĉ)Y-ĉ)Y-Ċ)Y-ċ)Y-Č)Y-č)Y-Ď)Y-ď))
# CPU times: total: 15.6 ms
# Wall time: 10.7 ms

# %% [markdown]
# Tiempo de ejecución: 10.7ms

# %%
g.visualizar_grafo(I1)

# %% [markdown]
# ## Regla 2

# %%
# %%time
A2 = g.reglas[1] 
r2 = SATsolver(A2)
I2= filtro(r2[1], A2)
# Out:
# CPU times: total: 15.6 ms
# Wall time: 13.2 ms

# %% [markdown]
# Tiempo de ejecución: 13.2ms

# %%
g.visualizar_grafo(I2)

# %% [markdown]
# ## Regla 3

# %%
# %%time
A3 = g.reglas[2]  
r3 = SATsolver(A3)
I3= filtro(r3[1], A3)
# Out:
# CPU times: total: 31.2 ms
# Wall time: 21.6 ms

# %% [markdown]
# Tiempo de ejecución: 21.6ms

# %%
g.visualizar_grafo(I3)

# %% [markdown]
# ## Regla 4

# %%
# %%time
A4 = g.reglas[3]  
r4 = SATsolver(A4)
I4= filtro(r4[1], A4)
# Out:
# CPU times: total: 5.28 s
# Wall time: 8.34 s

# %% [markdown]
# Tiempo de ejecución: 8.34s

# %%
g.visualizar_grafo(I4)

# %% [markdown]
# ## Regla 5

# %%
# %%time
A5 = g.reglas[4]  
r5 = SATsolver(A5)
I5= filtro(r5[1], A5)
# Out:
# CPU times: total: 422 ms
# Wall time: 607 ms

# %% [markdown]
# Tiempo de ejecución: 607ms

# %%
g.visualizar_grafo(I5)

# %% [markdown]
# ## Solución del problema

# %%
# %%time
A = Ytoria([g.reglas[0], g.reglas[1], g.reglas[2], g.reglas[3], g.reglas[4]])  
R = SATsolver(A)
I= filtro(R[1], A)
# Out:
# CPU times: total: 5.75 s
# Wall time: 8.78 s

# %% [markdown]
# Tiempo de ejecución: 8.78s

# %%
g.visualizar_grafo(I)
