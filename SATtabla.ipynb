# %% [markdown]
# ## SATtabla
# A continuación correremos cada una de las reglas con SATtabla y mostraremos su tiempo de ejecución.

# %%
from logica import*   
from grafos import*

# %%
g = Grafos()

# %%
A1 = inorder_to_tree(g.reglas[0])
# %time 
r1 = A1.SATtabla()
print(r1)
# Out:
# CPU times: total: 0 ns
# Wall time: 7.15 μs
# {'Ę': False, 'ğ': False, 'Ē': True, 'ě': False, 'ĝ': False, 'đ': False, 'ė': False, 'ē': False, 'Ĝ': False, 'Ė': False, 'ę': False, 'Ğ': False, 'Ě': False, 'Ĕ': False, 'ĕ': False, 'Đ': False}

# %%
g.visualizar_grafo(r1)

# %%
A2 = inorder_to_tree(g.reglas[1])
# %time 
r2 = A2.SATtabla()
print(r2)
# Out:
# CPU times: total: 0 ns
# Wall time: 7.15 μs
# {'ƀ': False, 'ƅ': False, 'Ə': False, 'Ƅ': False, 'Ƈ': False, 'ƍ': False, 'ƈ': True, 'Ǝ': False, 'Ɖ': False, 'ƌ': False, 'Ƃ': False, 'Ɓ': False, 'ƃ': False, 'Ƌ': False, 'Ɔ': False, 'Ɗ': False}

# %%
g.visualizar_grafo(r2)

# %%
A3 = inorder_to_tree(g.reglas[2])
# %time 
r3 = A3.SATtabla()
print(r3)

# %%
g.visualizar_grafo(r3)

# %%
A4 = inorder_to_tree(g.reglas[3])
# %time 
r4 = A4.SATtabla()
print(r4)

# %%
g.visualizar_grafo(r4)

# %%
A5 = inorder_to_tree(g.reglas[4])
# %time 
r5 = A5.SATtabla()
print(r5)
