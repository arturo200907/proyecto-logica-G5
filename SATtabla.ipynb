# %% [markdown]
# ## SATtabla
# A continuación correremos cada una de las reglas con SATtabla y mostraremos su tiempo de ejecución.

# %%
from logica import*   
from grafos import*

# %%
g = Grafos()

# %%
# %%time 
A1 = inorder_to_tree(g.reglas[0])

r1 = A1.SATtabla()
print(r1)
# Out:
# {'ą': False, 'Ć': False, 'Ā': True, 'č': False, 'Č': False, 'ď': False, 'Ď': False, 'Ĉ': False, 'ā': False, 'ć': False, 'ă': False, 'Ą': False, 'ċ': False, 'Ċ': False, 'Ă': False, 'ĉ': False}
# CPU times: total: 688 ms
# Wall time: 733 ms

# %% [markdown]
# Tiempo de ejecución: 688 ms

# %%
g.visualizar_grafo(r1)

# %%
# %%time 
A2 = inorder_to_tree(g.reglas[1])
r2 = A2.SATtabla()
print(r2)
# Out:
# {'Ŵ': False, 'Ź': False, 'ž': False, 'Ÿ': True, 'Ű': False, 'ŷ': False, 'ų': False, 'ű': False, 'Ż': False, 'ż': False, 'Ų': False, 'ź': False, 'Ž': False, 'Ŷ': False, 'ſ': False, 'ŵ': False}
# CPU times: total: 500 ms
# Wall time: 506 ms

# %% [markdown]
# Tiempo de ejecución: 500ms

# %%
g.visualizar_grafo(r2)

# %%
A3 = inorder_to_tree(g.reglas[2])
# %time 
r3 = A3.SATtabla()
print(r3)
# Out:
# CPU times: total: 0 ns
# Wall time: 6.44 μs
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 A3 = inorder_to_tree(g.reglas[2])
#       2 get_ipython().run_line_magic('time', '')
# ----> 3 r3 = A3.SATtabla()
#       4 print(r3)
#
# File c:\Users\Arturo\Documents\Proyecto LCC\proyecto-logica-G5\logica.py:77, in Formula.SATtabla(self)
#      75 letras = list(self.letras())
#      76 n = len(letras)
# ---> 77 valores = list(product([True, False], repeat=n))
#      78 for v in valores:
#      79     I = {letras[x]: v[x] for x in range(n)}
#
# MemoryError:

# %%
g.visualizar_grafo(r3)

# %%
A4 = inorder_to_tree(g.reglas[3])
# %time 
r4 = A4.SATtabla()
print(r4)

# %%
g.visualizar_grafo(r4)

# %%
A5 = inorder_to_tree(g.reglas[4])
# %time 
r5 = A5.SATtabla()
print(r5)
