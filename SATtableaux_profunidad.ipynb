# %% [markdown]
# ## SATtableaux por profundidad
# A continuación correremos cada una de las reglas con SATtableaux profundidad

# %%
from logica import*   
from grafos import*

# %%
g = Grafos()

# %% [markdown]
# ## Regla 1

# %%
# %%time
A1 = inorder_to_tree(g.reglas[0])
r1p = A1.SATtableaux_profundidad()
print(r1p)
# Out:
# {'ď': False, 'Ď': False, 'č': False, 'Č': False, 'ċ': False, 'Ċ': False, 'ĉ': False, 'Ĉ': False, 'ć': False, 'Ć': False, 'ą': False, 'ă': False, 'Ă': False, 'ā': False, 'Ą': True, 'Ā': False}
# CPU times: total: 46.9 ms
# Wall time: 41.6 ms

# %% [markdown]
# Tiempo de ejecución: 46.9ms

# %%
g.visualizar_grafo(r1p)

# %% [markdown]
# ## Regla 2

# %%
# %%time 
A2 = inorder_to_tree(g.reglas[1])
r2p = A2.SATtableaux_profundidad()
# Out:
# CPU times: total: 141 ms
# Wall time: 129 ms

# %% [markdown]
# Tiempo de ejecución: 141 ms

# %%
g.visualizar_grafo(r2p)

# %% [markdown]
# ## Regla 3

# %%
# %%time 
A3 = inorder_to_tree(g.reglas[2])
r3p = A3.SATtableaux_profundidad()
# Out:
# CPU times: total: 3min 18s
# Wall time: 7min 24s

# %% [markdown]
# Tiempo de ejecución: 7 minutos y 24 segundos

# %%
g.visualizar_grafo(r3p)

# %%
# %%time 
A4 = inorder_to_tree(g.reglas[3])
r4p = A4.SATtableaux_profundidad()
# Out:
# CPU times: total: 2.11 s
# Wall time: 3.94 s
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'A4 = inorder_to_tree(g.reglas[3])\nr4p = A4.SATtableaux_profundidad()\n')
#
# File c:\Users\Arturo\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# ...

# %% [markdown]
# Tiempo de ejecución: No ejecuto pues alcanzó stack overflow en 5.2s

# %%
g.visualizar_grafo(r4p)

# %%
# %%time 
A5 = inorder_to_tree(g.reglas[4])
r5p = A5.SATtableaux_profundidad()

# %% [markdown]
# Tiempo de ejecución: No se ejecutó después de 91 minutos y 16 segundos

# %%
g.visualizar_grafo(r5p)
